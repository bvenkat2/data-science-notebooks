# %% [markdown]
# # Graphing With Matplotlib
# One of the first steps in data science is often plotting data to get a sence of how its distributed. This notebook offers an introduction to graphing data with matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
x = np.linspace(0,100,100)
y = x
plt.plot(x,y)

# %%
x = np.linspace(-50,50,100)
y = [x_val ** 2 for x_val in x]
plt.plot(x,y)

# %%
x = np.random.rand(100)
y = np.random.rand(100)
plt.scatter(x,y)

# %%
import random 
x = pd.date_range('2012-10-01', periods=5, freq='5min')
start = 50
y = [start + random.random() * 10 for i in range(5)]
plt.plot(x,y)
# Out:
# /Users/bvenkat/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
df = pd.read_csv('Temperature_Data.csv')

# %%
plt.scatter(df['Temperature'], df['Anomaly'])
plt.title('Temperature Anomalies')
plt.xlabel('Temperature')
plt.ylabel('Anomaly')
# Out:
# Text(0, 0.5, 'Anomaly')

# %% [markdown]
# ## Exercises

# %% [markdown]
# Graph the function y = 4x^3

# %%
x = np.linspace(-50,50,100)
y = [4* (x_val ** 3) for x_val in x]
plt.plot(x,y)
